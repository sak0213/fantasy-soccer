# %%
import requests
from config import req_headers, base_url, focus_league, local_host, local_name, local_port, local_user
from creds import local_db_password
import psycopg2
import time
import json

# %%
conn = psycopg2.connect(dbname=local_name, user =local_user, host=local_host, password=local_db_password, port =local_port)
cur = conn.cursor()

# %%
endpoint = 'fixtures/lineups'
url = base_url + endpoint
season = 2023

# %%
fixture_list = []
fetch_teams_sql = """select id from ffl.fixtures where tracking_status = 'player_queried'"""
cur.execute(fetch_teams_sql)
for i in cur.fetchall():
    fixture_list.append(i[0])

# %%
fixture_insert_sql = """
insert into ffl_staging.query_data (
    job_id,
    query_scope,
    response_data,
    status
    )
    values
    (%s,%s,%s, %s)
    on conflict do nothing
    """

# %%
def parser(data=None, id_counter = None):
    job_id = id_counter
    query_scope = endpoint
    response_data = data


    return job_id, query_scope, json.dumps(response_data), 'loaded'

# %%
def fetch_response(params=None, page = None):
    if page == None:
        req = requests.get(url, params=params, headers=req_headers)

        return req.json()
    else:
        params['page'] = page
        req = requests.get(url, params=params, headers=req_headers)

        return req.json()

def load_responses(response_data=None, count_pass=None):
    cur.execute(fixture_insert_sql, (parser(response_data, count_pass)))

# %%
update_sql = """
update ffl.fixtures
set tracking_status = 'lineups_queried'
where id = %s
"""

# %%
for fixture in fixture_list[:96]:
    # time.sleep(30)
    print(f'starting new fixture id {fixture}')
    call_params = {
        'fixture':fixture
    }
    counter = 10000
    response = fetch_response(call_params)
    load_responses(response, counter)
    conn.commit()
    paging_needed = True
    
    while paging_needed == True:
        time.sleep(6.777)
        paging_current = response['paging']['current']
        paging_total = response['paging']['total']
        if paging_current == paging_total:
            paging_needed = False
            # print('paging not needed')
        elif paging_current != paging_total:
            next_page = paging_current + 1
            response = fetch_response(call_params, next_page)
            load_responses(response, counter)
            conn.commit()
        counter += 1
            # print(f'completed paging. page #{next_page}')
    cur.execute(update_sql, (fixture,))
    conn.commit()
    print(f'completed fixture with {counter} pages')
# Out:
# starting new fixture id 1035136
# completed fixture with 10001 pages
# starting new fixture id 1035039
# completed fixture with 10001 pages
# starting new fixture id 1035040
# completed fixture with 10001 pages
# starting new fixture id 1035041
# completed fixture with 10001 pages
# starting new fixture id 1035042
# completed fixture with 10001 pages
# starting new fixture id 1035043
# completed fixture with 10001 pages
# starting new fixture id 1035044
# completed fixture with 10001 pages
# starting new fixture id 1035045
# completed fixture with 10001 pages
# starting new fixture id 1035046
# completed fixture with 10001 pages
# starting new fixture id 1035047
# completed fixture with 10001 pages
# starting new fixture id 1035048
# completed fixture with 10001 pages
# starting new fixture id 1035049
# completed fixture with 10001 pages
# starting new fixture id 1035051
# completed fixture with 10001 pages
# starting new fixture id 1035052
# completed fixture with 10001 pages
# starting new fixture id 1035053
# completed fixture with 10001 pages
# starting new fixture id 1035054
# completed fixture with 10001 pages
# starting new fixture id 1035055
# completed fixture with 10001 pages
# starting new fixture id 1035056
# completed fixture with 10001 pages
# starting new fixture id 1035057
# completed fixture with 10001 pages
# starting new fixture id 1035058
# completed fixture with 10001 pages
# starting new fixture id 1035059
# completed fixture with 10001 pages
# starting new fixture id 1035060
# completed fixture with 10001 pages
# starting new fixture id 1035061
# completed fixture with 10001 pages
# starting new fixture id 1035062
# completed fixture with 10001 pages
# starting new fixture id 1035063
# completed fixture with 10001 pages
# starting new fixture id 1035064
# completed fixture with 10001 pages
# starting new fixture id 1035065
# completed fixture with 10001 pages
# starting new fixture id 1035066
# completed fixture with 10001 pages
# starting new fixture id 1035068
# completed fixture with 10001 pages
# starting new fixture id 1035069
# completed fixture with 10001 pages
# starting new fixture id 1035070
# completed fixture with 10001 pages
# starting new fixture id 1035071
# completed fixture with 10001 pages
# starting new fixture id 1035072
# completed fixture with 10001 pages
# starting new fixture id 1035073
# completed fixture with 10001 pages
# starting new fixture id 1035074
# completed fixture with 10001 pages
# starting new fixture id 1035075
# completed fixture with 10001 pages
# starting new fixture id 1035076
# completed fixture with 10001 pages
# starting new fixture id 1035077
# completed fixture with 10001 pages
# starting new fixture id 1035078
# completed fixture with 10001 pages
# starting new fixture id 1035079
# completed fixture with 10001 pages
# starting new fixture id 1035080
# completed fixture with 10001 pages
# starting new fixture id 1035081
# completed fixture with 10001 pages
# starting new fixture id 1035082
# completed fixture with 10001 pages
# starting new fixture id 1035083
# completed fixture with 10001 pages
# starting new fixture id 1035085
# completed fixture with 10001 pages
# starting new fixture id 1035086
# completed fixture with 10001 pages
# starting new fixture id 1035087
# completed fixture with 10001 pages
# starting new fixture id 1035088
# completed fixture with 10001 pages
# starting new fixture id 1035089
# completed fixture with 10001 pages
# starting new fixture id 1035090
# completed fixture with 10001 pages
# starting new fixture id 1035091
# completed fixture with 10001 pages
# starting new fixture id 1035092
# completed fixture with 10001 pages
# starting new fixture id 1035093
# completed fixture with 10001 pages
# starting new fixture id 1035094
# completed fixture with 10001 pages
# starting new fixture id 1035095
# completed fixture with 10001 pages
# starting new fixture id 1035096
# completed fixture with 10001 pages
# starting new fixture id 1035097
# completed fixture with 10001 pages
# starting new fixture id 1035098
# completed fixture with 10001 pages
# starting new fixture id 1035100
# completed fixture with 10001 pages
# starting new fixture id 1035101
# completed fixture with 10001 pages
# starting new fixture id 1035102
# completed fixture with 10001 pages
# starting new fixture id 1035103
# completed fixture with 10001 pages
# starting new fixture id 1035104
# completed fixture with 10001 pages
# starting new fixture id 1035105
# completed fixture with 10001 pages
# starting new fixture id 1035106
# completed fixture with 10001 pages
# starting new fixture id 1035107
# completed fixture with 10001 pages
# starting new fixture id 1035108
# completed fixture with 10001 pages
# starting new fixture id 1035109
# completed fixture with 10001 pages
# starting new fixture id 1035110
# completed fixture with 10001 pages
# starting new fixture id 1035111
# completed fixture with 10001 pages
# starting new fixture id 1035112
# completed fixture with 10001 pages
# starting new fixture id 1035113
# completed fixture with 10001 pages
# starting new fixture id 1035114
# completed fixture with 10001 pages
# starting new fixture id 1035115
# completed fixture with 10001 pages
# starting new fixture id 1035117
# completed fixture with 10001 pages
# starting new fixture id 1035118
# completed fixture with 10001 pages
# starting new fixture id 1035119
# completed fixture with 10001 pages
# starting new fixture id 1035120
# completed fixture with 10001 pages
# starting new fixture id 1035121
# completed fixture with 10001 pages
# starting new fixture id 1035122
# completed fixture with 10001 pages
# starting new fixture id 1035123
# completed fixture with 10001 pages
# starting new fixture id 1035124
# completed fixture with 10001 pages
# starting new fixture id 1035125
# completed fixture with 10001 pages
# starting new fixture id 1035126
# completed fixture with 10001 pages
# starting new fixture id 1035127
# completed fixture with 10001 pages
# starting new fixture id 1035128
# completed fixture with 10001 pages
# starting new fixture id 1035130
# completed fixture with 10001 pages
# starting new fixture id 1035131
# completed fixture with 10001 pages
# starting new fixture id 1035132
# completed fixture with 10001 pages
# starting new fixture id 1035133
# completed fixture with 10001 pages
# starting new fixture id 1035134
# completed fixture with 10001 pages
# starting new fixture id 1035137
# completed fixture with 10001 pages
# starting new fixture id 1035138
# completed fixture with 10001 pages
# starting new fixture id 1035139
# completed fixture with 10001 pages
# starting new fixture id 1035140
# completed fixture with 10001 pages
# starting new fixture id 1035141
# completed fixture with 10001 pages
