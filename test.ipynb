# %%
import requests
from config import req_headers, base_url

# %%
endpoint = 'fixtures/players'

fixture = 1035085

# %%
params = {
    'fixture':fixture
}

# %%
url = base_url+endpoint

# %%
req = requests.get(url, headers=req_headers, params=params)

# %%
response = req.json()

# %%
response
# Out:
# {'get': 'fixtures/players',
#  'parameters': {'fixture': '1035085'},
#  'errors': [],
#  'results': 2,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'team': {'id': 48,
#     'name': 'West Ham',
#     'logo': 'https://media.api-sports.io/football/teams/48.png',
#     'update': '2024-05-21T11:12:44+07:00'},
#    'players': [{'player': {'id': 253,
#       'name': 'Alphonse Aréola',
#       'photo': 'https://media.api-sports.io/football/players/253.png'},
#      'statistics': [{'games': {'minutes': 90,
#         'number': 23,
#         'position': 'G',
#         'rating': '8.6',
#         'captain': False,
#         'substitute': False},
#        'offsides': None,
#        'shots': {'total': None, 'on': None},
#        'goals': {'total': None, 'conceded': 3, 'assists': None, 'saves': 10},
#        'passes': {'total': 14, 'key': None, 'accuracy': '13'},
#        'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#        'duels': {'total': None, 'won': None},
# ...

# %%
team0 = response['response'][0]

# %%
test_player = team0['players'][0]
test_player_id = test_player['player']['id']
test_player['statistics'][0]

# %%
endpoint = 'players'
url = base_url + endpoint
params = {
    'id': test_player_id,
    'season':2023,
    'league':39
}

req = requests.get(url, headers=req_headers, params=params)

# %%
player_response = req.json()

# %%
player_response['response'][0]

# %%
endpoint = 'teams/players'
url = base_url + endpoint
params = {
    'id':48,
    'season':2023,
    'league':39
}

req = requests.get(url, headers=req_headers, params=params)

# %%
req.json()
# Out:
# {'get': 'teams/players',
#  'parameters': {'id': '48', 'season': '2023', 'league': '39'},
#  'errors': {'endpoint': 'The Teams/players endpoint does not exist.'},
#  'results': 0,
#  'paging': {'current': 1, 'total': 1},
#  'response': []}
