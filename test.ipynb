# %%
import requests
from config import req_headers, base_url

# %%
endpoint = 'fixtures/players'

fixture = 1035085

# %%
params = {
    'fixture':fixture
}

# %%
url = base_url+endpoint

# %%
req = requests.get(url, headers=req_headers, params=params)

# %%
response = req.json()

# %%
team0 = response['response'][0]

# %%
test_player = team0['players'][0]
test_player_id = test_player['player']['id']
test_player['statistics'][0]
# Out:
# {'games': {'minutes': 90,
#   'number': 23,
#   'position': 'G',
#   'rating': '8.6',
#   'captain': False,
#   'substitute': False},
#  'offsides': None,
#  'shots': {'total': None, 'on': None},
#  'goals': {'total': None, 'conceded': 3, 'assists': None, 'saves': 10},
#  'passes': {'total': 14, 'key': None, 'accuracy': '13'},
#  'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#  'duels': {'total': None, 'won': None},
#  'dribbles': {'attempts': None, 'success': None, 'past': None},
#  'fouls': {'drawn': None, 'committed': None},
#  'cards': {'yellow': 0, 'red': 0},
#  'penalty': {'won': None,
#   'commited': None,
#   'scored': 0,
#   'missed': 0,
#   'saved': 0}}

# %%
endpoint = 'players'
url = base_url + endpoint
params = {
    'id': test_player_id,
    'season':2023
}

req = requests.get(url, headers=req_headers, params=params)

# %%
player_response = req.json()

# %%
player_response['response'][0]['statistics']
# Out:
# [{'team': {'id': 48,
#    'name': 'West Ham',
#    'logo': 'https://media.api-sports.io/football/teams/48.png'},
#   'league': {'id': 39,
#    'name': 'Premier League',
#    'country': 'England',
#    'logo': 'https://media.api-sports.io/football/leagues/39.png',
#    'flag': 'https://media.api-sports.io/flags/gb.svg',
#    'season': 2023},
#   'games': {'appearences': 31,
#    'lineups': 31,
#    'minutes': 2702,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': '7.377419',
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 3, 'bench': 2},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': 53, 'assists': 0, 'saves': 138},
#   'passes': {'total': 718, 'key': None, 'accuracy': 13},
#   'tackles': {'total': 1, 'blocks': None, 'interceptions': 1},
#   'duels': {'total': 20, 'won': 15},
#   'dribbles': {'attempts': 1, 'success': 1, 'past': None},
#   'fouls': {'drawn': 3, 'committed': 2},
#   'cards': {'yellow': 1, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': 0,
#    'missed': 0,
#    'saved': 2}},
#  {'team': {'id': 48,
#    'name': 'West Ham',
#    'logo': 'https://media.api-sports.io/football/teams/48.png'},
#   'league': {'id': 48,
#    'name': 'League Cup',
#    'country': 'England',
#    'logo': 'https://media.api-sports.io/football/leagues/48.png',
#    'flag': 'https://media.api-sports.io/flags/gb.svg',
#    'season': 2023},
#   'games': {'appearences': 1,
#    'lineups': 1,
#    'minutes': 90,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': '6.200000',
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 1},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': 5, 'assists': None, 'saves': 6},
#   'passes': {'total': 35, 'key': None, 'accuracy': 17},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#   'duels': {'total': None, 'won': None},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': None, 'committed': None},
#   'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': 0,
#    'missed': 0,
#    'saved': 0}},
#  {'team': {'id': 48,
#    'name': 'West Ham',
#    'logo': 'https://media.api-sports.io/football/teams/48.png'},
#   'league': {'id': 45,
#    'name': 'FA Cup',
#    'country': 'England',
#    'logo': 'https://media.api-sports.io/football/leagues/45.png',
#    'flag': 'https://media.api-sports.io/flags/gb.svg',
#    'season': 2023},
#   'games': {'appearences': 0,
#    'lineups': 0,
#    'minutes': 0,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': None,
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 2},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': 0, 'assists': None, 'saves': None},
#   'passes': {'total': None, 'key': None, 'accuracy': None},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#   'duels': {'total': None, 'won': None},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': None, 'committed': None},
#   'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': 0,
#    'missed': 0,
#    'saved': 0}},
#  {'team': {'id': 48,
#    'name': 'West Ham',
#    'logo': 'https://media.api-sports.io/football/teams/48.png'},
#   'league': {'id': 3,
#    'name': 'UEFA Europa League',
#    'country': 'World',
#    'logo': 'https://media.api-sports.io/football/leagues/3.png',
#    'flag': None,
#    'season': 2023},
#   'games': {'appearences': 1,
#    'lineups': 1,
#    'minutes': 90,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': '6.700000',
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 7},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': 2, 'assists': None, 'saves': 3},
#   'passes': {'total': 23, 'key': None, 'accuracy': 20},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#   'duels': {'total': None, 'won': None},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': None, 'committed': None},
#   'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': 0,
#    'missed': 0,
#    'saved': 0}},
#  {'team': {'id': 48,
#    'name': 'West Ham',
#    'logo': 'https://media.api-sports.io/football/teams/48.png'},
#   'league': {'id': 667,
#    'name': 'Friendlies Clubs',
#    'country': 'World',
#    'logo': 'https://media.api-sports.io/football/leagues/667.png',
#    'flag': None,
#    'season': 2023},
#   'games': {'appearences': 0,
#    'lineups': 0,
#    'minutes': 0,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': None,
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 0},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': None, 'assists': None, 'saves': None},
#   'passes': {'total': None, 'key': None, 'accuracy': None},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#   'duels': {'total': None, 'won': None},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': None, 'committed': None},
#   'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': None,
#    'missed': None,
#    'saved': None}},
#  {'team': {'id': 2,
#    'name': 'France',
#    'logo': 'https://media.api-sports.io/football/teams/2.png'},
#   'league': {'id': 960,
#    'name': 'Euro Championship - Qualification',
#    'country': 'World',
#    'logo': 'https://media.api-sports.io/football/leagues/960.png',
#    'flag': None,
#    'season': 2023},
#   'games': {'appearences': 0,
#    'lineups': 0,
#    'minutes': 0,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': None,
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 8},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': 0, 'assists': None, 'saves': None},
#   'passes': {'total': None, 'key': None, 'accuracy': None},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#   'duels': {'total': None, 'won': None},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': None, 'committed': None},
#   'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': 0,
#    'missed': 0,
#    'saved': 1}},
#  {'team': {'id': 2,
#    'name': 'France',
#    'logo': 'https://media.api-sports.io/football/teams/2.png'},
#   'league': {'id': 10,
#    'name': 'Friendlies',
#    'country': 'World',
#    'logo': 'https://media.api-sports.io/football/leagues/10.png',
#    'flag': None,
#    'season': 2023},
#   'games': {'appearences': 0,
#    'lineups': 0,
#    'minutes': 0,
#    'number': None,
#    'position': 'Goalkeeper',
#    'rating': None,
#    'captain': False},
#   'substitutes': {'in': 0, 'out': 0, 'bench': 2},
#   'shots': {'total': None, 'on': None},
#   'goals': {'total': 0, 'conceded': None, 'assists': None, 'saves': None},
#   'passes': {'total': None, 'key': None, 'accuracy': None},
#   'tackles': {'total': None, 'blocks': None, 'interceptions': None},
#   'duels': {'total': None, 'won': None},
#   'dribbles': {'attempts': None, 'success': None, 'past': None},
#   'fouls': {'drawn': None, 'committed': None},
#   'cards': {'yellow': 0, 'yellowred': 0, 'red': 0},
#   'penalty': {'won': None,
#    'commited': None,
#    'scored': None,
#    'missed': None,
#    'saved': None}}]
